# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyeshRaoBK/EDA-AIR-BNB-booking-analysis/blob/main/AIRBNB_BOOKING_ANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member  -**  - Priyesh Rao B K

# %% [markdown]
# # **Project Summary -**
# The Exploratory Data Analysis (EDA) of Airbnb booking analysis is a critical component of the overall project aimed at understanding the various factors that influence customer booking decisions on the Airbnb platform. The EDA will provide insights into the patterns and trends in the booking data and identify any underlying relationships between variables that may impact customer behavior.
#
# The EDA will begin with data collection from the Airbnb platform, including information on the listings, their availability, prices, and customer reviews. The data will then be cleaned to remove any missing, inconsistent, or irrelevant information. The next phase of the EDA will involve data analysis to uncover patterns and trends in customer behavior, such as the most popular listing types, the most sought-after amenities, and the factors that impact booking rates.
#
# Data visualization will be used to effectively communicate the insights and findings of the data analysis. A combination of graphs, charts, and maps will be used to showcase the trends and patterns in the data. This will help to identify areas of opportunity and highlight areas that require improvement.
#
# The final phase of the EDA will involve summarizing the findings and providing recommendations on how the insights can be leveraged to improve the customer experience and increase booking rates. This will include recommendations on optimizing pricing strategies, enhancing the listing descriptions, and improving the overall customer experience. The findings and recommendations will be presented in a comprehensive report, detailing the methodology, findings, and recommendations.
#
# In conclusion, the EDA of Airbnb booking analysis will provide valuable insights into the patterns and relationships in the booking data and inform the development of predictive models that can be used to optimize the platform. The EDA will play a crucial role in ensuring the success of the overall Airbnb booking analysis project by providing a foundation for further analysis and optimization. The insights and recommendations generated by the EDA will help to drive growth and success for the Airbnb platform and ensure its continued evolution and adaptation to changing customer needs and preferences.

# %% [markdown]
# # **GitHub Link -**
# https://github.com/PriyeshRaoBK/EDA-AIR-BNB-booking-analysis/blob/main/AIRBNB_BOOKING_ANALYSIS.ipynb

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# To explore and understand the patterns and trends in the Airbnb booking data and to identify any underlying relationships between variables that may impact customer booking decisions."
#
# This problem statement highlights the need to gain a deeper understanding of the underlying patterns and relationships in the Airbnb booking data. The objective of the EDA is to uncover any trends, patterns, or anomalies in the data that may have an impact on customer booking decisions.
#
# The EDA will be an important step in the overall Airbnb booking analysis project as it will help to identify areas of opportunity and highlight areas that require improvement. By conducting an in-depth analysis of the data, the EDA will provide insights into the factors that influence customer behavior and inform the development of predictive models that can be used to optimize the platform.
#
# Ultimately, the EDA will play a crucial role in ensuring the success of the Airbnb booking analysis project by providing a foundation for further analysis and optimization. By exploring and understanding the patterns and trends in the data, the project team will be better equipped to make informed decisions and to drive growth and success for the Airbnb platform.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
#Import plotting packages
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
#reading data frame
file_path = '/content/drive/MyDrive/Almabetter/Airbnb NYC 2019.csv'
df=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df1 = df.groupby(df.columns.tolist(), as_index=False).size()
df2 = len(df)-len(df.drop_duplicates())
print(df2)

# %%
df1

# %% [markdown]
# #There is no duplicate rows in this data frame.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
#find percentage of missing values for each column
listings_missing_df = df.isnull().mean()*100

#filter out only columns, which have missing values
listings_columns_with_nan = listings_missing_df[listings_missing_df > 0]
# Visualizing the missing values
#plot the results
listings_columns_with_nan.plot.bar(title='Missing values per column, %')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 0.5% of data is missing in coumn name and host name. 20% of data is missing for rev last_review and reviews_per_month. Since it is less than 50% we can consider this rows for further analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe

# %% [markdown]
# After checking the data id is unique number for each booking. Hence it is neglected. host_id and host_name are related but host_name is the name of the host where two differen host can have same name Hence for analysis we have neglected host_naame and considered host_id.

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# 48895 Row, 16 - Column
#
# Categorical data : host name, neighbourhood_group, neighbourhood, room_type
#
# Data Has int, float and object data type
#
# Id : It is unique for each bookings, numeric values, data is not repeatable.
#
# name : How is the room. Ex : Clean & quiet apt home by the park, this can be neglected.
#
# host_id : ID of the host, Data is repeatable, Numerical data .
#
# host_name : Name of the host. This column is neglected, Categorical data .
#
# neighbourhood_group : It is borough (a town that has its own goverment ). Brooklyn,Manhattan, Queens, Bronx, Staten Island .
#
# Neighbourhood: Place of the location inside neighborhood group.
#
# Latitude : Numerical values , Position of the location.
#
# Longitude :Numerical values , Position of the location.
#
# room_type : Private, Shared or Entire/Home, Categorical value.
#
# price : Cost of the room, Numerical value.
#
# minimum_nights : How many days compulsory to stay.
#
# number_of_reviews : Total number of review for this host
#
# last_review : Give information regarding last reviews is given in date.
#
# reviews_per_month : Total number of reviews / Days in months
#
# calculated_host_listings_count : The total number of apartments and bedrooms referred to the same landlord.
#
# availability_365 : Days it is available in a year

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
unique_counts = df.nunique()
print(unique_counts)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# filling missing value using fillna() 
df1=df.fillna(0)

# %%
#duplicate row value delete
df=df.drop_duplicates(inplace = True)

# %%
#understnading difference between host_name and host_id
#finding number of unique values in host name
n = len(pd.unique(df['host_name']))
  
print("No.of.unique values :", 
      n)

# %%
#length of unque values in host_id
n = len(pd.unique(df['host_id']))
  
print("No.of.unique values :", 
      n)

# %%
#host_name values count
df['host_name'].value_counts()

# %%
#host_id values counts
df['host_id'].value_counts()

# %%
#checking host name sonder(NYC) and counts
df[df['host_name']=="Sonder (NYC)"].count()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Duplicate rows are deleted. Null values replaced with zero. Here we can analyse that host_id will be same if same person hosted same propety at multiple times and also property name and host name is insignificant. so we can exclude them from the datasetAnswer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 TOP 20 neighbourhood

# %%
#plotting bar chart for most visting place 
#selecting top 40 neighbourhood where people visit
data2 = {'count_neighbourhood':df['neighbourhood'].value_counts() }
chart1 = pd.DataFrame(data2)
#plt.figure(figsize=(60,15))
chart1.head()
from matplotlib.pyplot import figure
plt.rcParams['figure.figsize'] = (45, 15)
#plt.figure(figsize=(1,15))
chart1.iloc[0:20].plot.bar(color=['green'])
plt.xticks(fontsize=15)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart helps to undestand which neighbourhodd highly visited

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart I came to know, top 20 neighbouhood group in newyork city where more bookings happen.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this analysis it helps to understand for which place  most people visit and So that if there is any properties present in this area then he will get regular customer and more profitable

# %% [markdown]
# #### Chart - 2 TOP 10 host_id

# %%
# Chart - 2 visualization code
data3 = {'count_hostid':df['host_id'].value_counts() }
chart2 = pd.DataFrame(data3)
#plt.figure(figsize=(60,15))
chart2.head()
from matplotlib.pyplot import figure
plt.rcParams['figure.figsize'] = (45, 15)
#plt.figure(figsize=(1,15))
chart2.iloc[0:10].plot.bar(color=['yellow'])
plt.xticks(fontsize=15)

# %%
#top 40 host_name
data4={'count_host_id':df['host_name'].value_counts() }
bkk = pd.DataFrame(data4)
plt.rcParams['figure.figsize'] = (50, 20)
#plt.figure(figsize=(1,15))
bkk.iloc[0:10].plot.bar()
plt.xticks(fontsize=20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# Above two chart helps to undestand which host has highest number properties hosted.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows tops 10 host_id  hosting properties in AIRBNB

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
# It gives information top hos_id. Here hostname is used inly for vizulization puropose becuase host_name cant give accurate results. By knowing to top property holder we can further analysi price, which place he is hosting and how he is sucessful

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3 houses hosted in different neighbourhood group

# %%
# Chart - 3 visualization code
#bookings based on neighbouhood group
data3 = {'count_neighbourhood_group':df['neighbourhood_group'].value_counts() }
akk = pd.DataFrame(data3)
plt.rcParams['figure.figsize'] = (10, 5)
akk.plot.bar()
plt.xticks(fontsize=15)

# %%
#pie chart for neighbourhood group.
plt.style.use('fivethirtyeight')
plt.figure(figsize=(23,17))
plt.title("Neighbourhood Group")
g = plt.pie(df.neighbourhood_group.value_counts(), labels=df.neighbourhood_group.value_counts().index,autopct='%1.1f%%', startangle=90)
plt.show()

# %%
#using longitude and latitude to draw scatterplot  to understand hosting properties in different neighbourhood group

sns.scatterplot(data=df, x='longitude', y='latitude', hue='neighbourhood_group'); 
plt.rcParams['font.size'] = 20
#plt.xticks(fontsize=20)  
#plt.yticks(fontsize=20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Above 3 chart bar, pie and scatter plot gives information of houses hosted in different neighbourhood group

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this it is clear that Manhattan and broklyn are the top places where highest number of property hosted in airbnb  followed by Queens, Bronx and StatenIsland

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this it is clear that properties in manhattan and broklyn has higest properties which result in high compition between host.

# %% [markdown]
# #### Chart - 4

# %%
# distribution curve for price
sns.kdeplot(data = df['price'])
plt.xlim([0,2000]) 
plt.xlabel("Price", size=20)
plt.xticks(fontsize=20)  
plt.ylabel("Frequency", size=20)
plt.yticks(fontsize=20)                
plt.grid(True, alpha=0.3, linestyle="--")     
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart gives the information of price which has high frequency in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the property price is  in between 0 to 250 dollar range

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Most of the property hosted in AIRBNB has a priced of 0 to 250 dollar and next is 250 to 500 dollars.

# %% [markdown]
# #### Chart - 5 Availability room

# %%
# Chart - 6 visualization code
#considering rows above 0 for availabilty of romm
df2 = df.loc[df["availability_365"] > 0 ]

#box plot for availability room
plt.style.use('classic')
plt.figure(figsize=(13,7))
plt.title("Neighbourhood Group vs. Availability Room")
sns.boxplot(data=df2, x='neighbourhood_group',y='availability_365',palette="dark")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This boxplot gives information of availability room in newyork

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Mean of staten island  availability room is 250 days which is higest. Manhattan, Queens and Bronx availabity room is same 160 days , Broklyn has the lowest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this analysis we came to know that eventhough Broklyn and Manhattan has higest number of rooms but there availabilty is very lesss when compared to staten Island. This can be one of the reason where customer wil miiss the room in this region because of there lees availability.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# considering  the price greater than  zero 
df3 = df.loc[df["price"] > 0 ]
# boxplot for price distribution
plt.style.use('classic')
plt.figure(figsize=(13,7))
plt.title("Neighbourhood Group Price Distribution < 500")
sns.boxplot(y="price",x ='neighbourhood_group' ,data = df3[df3.price<500])
plt.show()

# %%
#considering the price grater than zero
df4 = df.loc[df["price"] > 0 ]

plt.figure(figsize=(23,17))
sns.violinplot( x =df4['neighbourhood_group'], y = df4["price"] )

plt.ylim([0,600])

plt.xticks(fontsize=15)
plt.yticks(fontsize=20)

# %%
# scatter plot foe price distribution at different negbourhood group
plt.figure(figsize=(23,17))
plt.rcParams['figure.figsize'] = (50, 20)
sns.stripplot(x=df['neighbourhood_group'], y=df['price'])
plt.xticks(fontsize=15)
plt.yticks(fontsize=20)

# %%
#boxplot of price distributio of top host 
plt.style.use('classic')
plt.figure(figsize=(13,7))
plt.title("Neighbourhood Group Price Distribution < 500")
sns.boxplot(y="price",x ='host_id' ,data = df[df.host_id=="host_id"])
plt.show()

# %%
#using longitude and latitude to draw scatterplot  to undestand price distribution
import urllib
#initializing the figure size
plt.figure(figsize=(10,8))
#loading the png NYC image found on Google and saving to my local folder along with the project
i=urllib.request.urlopen('https://upload.wikimedia.org/wikipedia/commons/e/ec/Neighbourhoods_New_York_City_Map.PNG')
nyc_img=plt.imread(i)
#scaling the image based on the latitude and longitude max and mins for proper output
plt.imshow(nyc_img,zorder=0,extent=[-74.258, -73.7, 40.49,40.92])
ax=plt.gca()
#using scatterplot again
df1=df[df.price<500]
df1.plot(kind='scatter', x='longitude', y='latitude', label='availability_365', c='price', ax=ax, 
           cmap=plt.get_cmap('jet'), colorbar=True, alpha=0.4, zorder=5)

plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here I have done several plot for the price analysis. Box Plot, Violin plot, Scatter plot and final using longitude-latitude plotted price distribution in different areas.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# For the box plot, I have analyzed a price under 500 dollar. Since the majority of the property cost less than 500. In this, I found the average price of a property in Manhattan is 150 dollars followed by Brooklyn at around 90 dollars, Queen, Staten Island, and the Bronx have a very similar mean price of 80 dollars. There are many outliers in manhattan so the costliest property is in manhattan followed by Brooklyn. This information can also be seen in the violin plot. From the scatter plot, you can see that there are properties that cost 10000 dollars in Manhattan and Brooklyn. Most of the costliest property is available in these two areas. This observation is shown in longitude- latitude plot. Prices above 400 dollars are shown in red and less than 150 dollars are shown in blue. Finally, I have drawn a box plot for the highest property holder host_id and

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer HereFrom this analysis, most of the hosts host a price of fewer than 500 dollars. This gives information that people prefer lower-priced places than  costlier places.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# barchart for room type
plt.figure(figsize=(13,7))
plt.title("Type of Room")
sns.countplot(df.room_type, palette="muted")
fig = plt.gcf()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Chart represent number of private, entier house and shared room present in the New York .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Number of entire home preoperty is the highest followed by private rooom. SHared room is the least number of property present in the AIRBNB.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this we can analyse that most of the property available in AIRBNB in entire home followed by private room. Having this kind of property is profitable rather than doing  shared room

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# scatter plot for reviews per month based on neighbourg$hood
plt.figure(figsize=(23,17))
sns.stripplot(x=df['neighbourhood_group'], y=df['reviews_per_month'])
plt.ylim([0,20]) 
plt.xticks(fontsize=15)
plt.yticks(fontsize=20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10 Correlation Heatmap

# %%
# Chart - 10 visualization code
#correlation plot
corr = df.corr(method='kendall')
plt.figure(figsize=(13,10))
plt.title("Correlation Between Different Variables\n")
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Above is the corellation chart for AIR BNB Booking Analysis

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Ther is no much relation between any column .  review_per_month and number_reviews are little  corelated which does not give any insigts.
# avai

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11 - Pair Plot

# %%
# Chart - 11 visualization code
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Conclusion
# In this analysis project, about 14 different cases were analyzed on the given dataset to make better business decisions and help analyze trends, which can lead to new and better products and services. It has been found that Most of the Bookings were takes place for the "Manhaton" of around “44.3%" followed by “Brooklyn", “Queens" which has “41.1%" & "11.6%" respectively.
#
# We have also analyzed that, Manhattan has the highest range price for the listings with about dollar 140 as an average price, followed by Brooklyn with $90 per night, Queens and Staten Island seem to have a very similar distribution, The Bronx is the cheapest.
#
# Additionally, we also find-out the Top (Host). Preference of Guests w.r.t. Property Type & Room Type. Furthermore, we have also been analyzed Customer Reviews/Comments, provided by the Airbnb’s and many more.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
